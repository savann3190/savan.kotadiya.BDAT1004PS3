# %% [markdown]
# # Question 1

# %%
#step 1
import pandas as pd
import numpy as np

# %%
#step 2
#step 3
User = pd.read_csv('user_id.txt',sep = '|')

# %%
User
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
#step 4
User_data.groupby('occupation').age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
#step 5
User_data.groupby('occupation').gender.count().sort_values(ascending = False)
# Out:
# occupation
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# lawyer            12
# salesman          12
# none               9
# homemaker          7
# doctor             7
# Name: gender, dtype: int64

# %%
#step 6
User_data.groupby('occupation').age.min()
# Out:
# occupation
# administrator    21
# artist           19
# doctor           28
# educator         23
# engineer         22
# entertainment    15
# executive        22
# healthcare       22
# homemaker        20
# lawyer           21
# librarian        23
# marketing        24
# none             11
# other            13
# programmer       20
# retired          51
# salesman         18
# scientist        23
# student           7
# technician       21
# writer           18
# Name: age, dtype: int64

# %%
#step 6
User_data.groupby('occupation').age.max()
# Out:
# occupation
# administrator    70
# artist           48
# doctor           64
# educator         63
# engineer         70
# entertainment    50
# executive        69
# healthcare       62
# homemaker        50
# lawyer           53
# librarian        69
# marketing        55
# none             55
# other            64
# programmer       63
# retired          73
# salesman         66
# scientist        55
# student          42
# technician       55
# writer           60
# Name: age, dtype: int64

# %%
#step 7
User_data.groupby(['occupation', 'gender']).age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
User_data.groupby(['occupation', 'gender']).count()
# Out:
#                       user_id  age  zip_code
# occupation    gender
# administrator F            36   36        36
#               M            43   43        43
# artist        F            13   13        13
#               M            15   15        15
# doctor        M             7    7         7
# educator      F            26   26        26
#               M            69   69        69
# engineer      F             2    2         2
#               M            65   65        65
# entertainment F             2    2         2
#               M            16   16        16
# executive     F             3    3         3
#               M            29   29        29
# healthcare    F            11   11        11
#               M             5    5         5
# homemaker     F             6    6         6
#               M             1    1         1
# lawyer        F             2    2         2
#               M            10   10        10
# ...

# %% [markdown]
# # Question 2

# %%
#step 1
import numpy as np
import pandas as pd

# %%
#step 2
#step 3
euro12 = pd.read_csv('euro12.txt')
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#step4
euro12.Goals
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
#step 5
euro12.Team.count()
# Out:
# 16

# %%
#step 6
euro12.shape[1]
# Out:
# 35

# %%
#step7
discipline =  euro12[['Team','Yellow Cards','Red Cards']]
discipline.head()
# Out:
#              Team  Yellow Cards  Red Cards
# 0         Croatia             9          0
# 1  Czech Republic             7          0
# 2         Denmark             4          0
# 3         England             5          0
# 4          France             6          0

# %%
#step 8
discipline.sort_values(['Yellow Cards', 'Red Cards'])
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0
# 11  Republic of Ireland             6          1
# 9                Poland             7          1
# 6                Greece             9          1

# %%
#step 9 
euro12['Yellow Cards'].mean()
# Out:
# 7.4375

# %%
#step 10
euro12[euro12['Goals'] > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
#step 11
euro12[euro12.Team.str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
#step 12
euro12.iloc[:, 0:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#step 13
euro12.iloc[:, 0:-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#step14
euro12.loc[euro12.Team.isin(['England','Italy','Russia']), ['Team', 'Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# # Question 3

# %%
#step1
import numpy as np
import pandas as pd
import random

# %%
#step 2
alpha = pd.Series(np.random.randint(1,5,100))
beta = pd.Series(np.random.randint(1,4,100))
gema = pd.Series(np.random.randint(10000,30000,100))

# %%
#step 3
df = pd.concat([alpha, beta, gema], axis=1)
df
# Out:
#     0  1      2
# 0   3  2  26986
# 1   4  3  12374
# 2   4  3  10012
# 3   4  3  15000
# 4   1  2  11563
# .. .. ..    ...
# 95  3  2  29151
# 96  4  3  19315
# 97  2  1  20540
# 98  1  3  25651
# 99  2  2  26784
#
# [100 rows x 3 columns]

# %%
#step 4
df.columns = ['bedrs','bathrs','price_sqr_meter']
df
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       3       2            26986
# 1       4       3            12374
# 2       4       3            10012
# 3       4       3            15000
# 4       1       2            11563
# ..    ...     ...              ...
# 95      3       2            29151
# 96      4       3            19315
# 97      2       1            20540
# 98      1       3            25651
# 99      2       2            26784
#
# [100 rows x 3 columns]

# %%
#step5
bigcolumn = pd.concat([alpha,beta,gema], axis = 0)
bigcolumn
# Out:
# 0         3
# 1         4
# 2         4
# 3         4
# 4         1
#       ...
# 95    29151
# 96    19315
# 97    20540
# 98    25651
# 99    26784
# Length: 300, dtype: int32

# %%
#step6
len(bigcolumn)
# Out:
# 300

# %%
#step7
bigcolumn.reset_index(drop = True , inplace = True)
bigcolumn
# Out:
# 0          3
# 1          4
# 2          4
# 3          4
# 4          1
#        ...
# 295    29151
# 296    19315
# 297    20540
# 298    25651
# 299    26784
# Length: 300, dtype: int32

# %% [markdown]
# # Question 4

# %%
#step 1
import pandas as pd
import numpy as np
import datetime as dt

# %%
#step2
Data = pd.read_csv('wind.txt',sep=' ')
Data
# Out:
#       Yr    Mo    Dy  Unnamed: 3  Unnamed: 4    RPT  Unnamed: 6  Unnamed: 7  \
# 0     61   NaN   1.0         NaN        1.00  15.04       14.96       13.17
# 1     61   NaN   1.0         NaN        2.00  14.71         NaN         NaN
# 2     61   NaN   1.0         NaN        3.00  18.50       16.88       12.33
# 3     61   NaN   1.0         NaN        4.00  10.58         NaN        6.63
# 4     61   NaN   1.0         NaN        5.00  13.33       13.25       11.42
# ...   ..   ...   ...         ...         ...    ...         ...         ...
# 6569  78  12.0  27.0       17.58       16.96  17.62         NaN        8.08
# 6570  78  12.0  28.0       13.21         NaN   5.46       13.46         NaN
# 6571  78  12.0  29.0       14.00       10.29  14.42         NaN        8.71
# 6572  78  12.0  30.0       18.50       14.04  21.29         NaN        9.13
# 6573  78  12.0  31.0       20.33       17.41  27.29         NaN        9.59
#
# ...

# %%
#step3
data =pd.read_csv('wind.txt',sep="\s+")
data.head(3)
# Out:
#    Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  61   1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  61   1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  61   1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71

# %%
#step6
data.isnull().sum()
# Out:
# Yr     0
# Mo     0
# Dy     0
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %%
#step7
data.notnull().sum()
# Out:
# Yr     6574
# Mo     6574
# Dy     6574
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %%
#step8
#step 8
data.mean().mean()
# Out:
# 14.299199599246556

# %%
#step9
loc_stats = pd.DataFrame()
loc_stats['min'] = data.min()
loc_stats['max'] = data.max()
loc_stats['mean'] = data.mean()
loc_stats['std'] = data.std()
loc_stats
# Out:
#        min    max       mean       std
# Yr   61.00  78.00  69.500304  5.188131
# Mo    1.00  12.00   6.523274  3.448871
# Dy    1.00  31.00  15.728628  8.800335
# RPT   0.67  35.80  12.362987  5.618413
# VAL   0.21  33.37  10.644314  5.267356
# ROS   1.50  33.84  11.660526  5.008450
# KIL   0.00  28.46   6.306468  3.605811
# SHA   0.13  37.54  10.455834  4.936125
# BIR   0.00  26.16   7.092254  3.968683
# DUB   0.00  30.37   9.797343  4.977555
# CLA   0.00  31.08   8.495053  4.499449
# MUL   0.00  25.88   8.493590  4.166872
# CLO   0.04  28.21   8.707332  4.503954
# BEL   0.13  42.38  13.121007  5.835037
# MAL   0.67  42.54  15.599079  6.699794

# %%
#step10
day_stats = pd.DataFrame()
day_stats['min'] = data.min()
day_stats['max'] = data.max()
day_stats['mean'] = data.mean()
day_stats['std'] = data.std()
day_stats
# Out:
#        min    max       mean       std
# Yr   61.00  78.00  69.500304  5.188131
# Mo    1.00  12.00   6.523274  3.448871
# Dy    1.00  31.00  15.728628  8.800335
# RPT   0.67  35.80  12.362987  5.618413
# VAL   0.21  33.37  10.644314  5.267356
# ROS   1.50  33.84  11.660526  5.008450
# KIL   0.00  28.46   6.306468  3.605811
# SHA   0.13  37.54  10.455834  4.936125
# BIR   0.00  26.16   7.092254  3.968683
# DUB   0.00  30.37   9.797343  4.977555
# CLA   0.00  31.08   8.495053  4.499449
# MUL   0.00  25.88   8.493590  4.166872
# CLO   0.04  28.21   8.707332  4.503954
# BEL   0.13  42.38  13.121007  5.835037
# MAL   0.67  42.54  15.599079  6.699794

# %% [markdown]
# # Question 5

# %%
#step 1
import pandas as pd
import numpy as np

# %%
#step 2
#step3

chipo = pd.read_csv('order.txt', sep='\t')
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
#step4
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
#step5
chipo.shape[0]
# Out:
# 4622

# %%
#step6
chipo.shape[1]
# Out:
# 5

# %%
#step7
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#step8
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
#step9
chipo[chipo.quantity == chipo.quantity.max()].item_name
# Out:
# 3598    Chips and Fresh Tomato Salsa
# Name: item_name, dtype: object

# %%
#step10
chipo[chipo.quantity == chipo.quantity.max()].quantity
# Out:
# 3598    15
# Name: quantity, dtype: int64

# %%
#step11
chipo.groupby('choice_description').agg({'quantity':'sum'}).sort_values(by='quantity')
# Out:
#                                                     quantity
# choice_description
# [Adobo-Marinated and Grilled Chicken, Pinto Bea...         1
# [Tomatillo Green Chili Salsa, [Fajita Vegetable...         1
# [Tomatillo Green Chili Salsa, [Fajita Vegetable...         1
# [Tomatillo Green Chili Salsa, [Fajita Vegetable...         1
# [Tomatillo Green Chili Salsa, [Fajita Vegetable...         1
# ...                                                      ...
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...        42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...        49
# [Sprite]                                                  89
# [Coke]                                                   143
# [Diet Coke]                                              159
#
# [1043 rows x 1 columns]

# %%
#step12
chipo.quantity.sum()
# Out:
# 4972

# %%
#step13
def order_float(x):
    return float(x[1:-1])
chipo.item_price = chipo.item_price.apply(order_float)
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
chipo.item_price.dtype
# Out:
# dtype('float64')

# %%
#step14
chipo.item_price.sum()
# Out:
# 34500.16

# %%
#step15
chipo.order_id.value_counts().count()
# Out:
# 1834

# %%
#step16
chipo.item_price.mean()
# Out:
# 7.464335785374397

# %%
#step17
chipo.item_price.mean()
# Out:
# 7.464335785374397

# %% [markdown]
# # Question 6

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
US_divorce = pd.read_csv('us-marriages-divorces-1867-2014.csv')
US_divorce
# Out:
#      Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0    1867   357000.0   10000.0    36970000                 9.7
# 1    1868   345000.0   10000.0    37885000                 9.1
# 2    1869   348000.0   11000.0    38870000                 9.0
# 3    1870   352000.0   11000.0    39905000                 8.8
# 4    1871   359000.0   12000.0    41010000                 8.8
# ..    ...        ...       ...         ...                 ...
# 140  2007  2197000.0  856000.0   301696000                 7.3
# 141  2008  2157000.0  844000.0   304543000                 7.1
# 142  2009  2080000.0  840000.0   307240000                 6.8
# 143  2010  2096000.0  872000.0   309776000                 6.8
# 144  2011  2118000.0  877000.0   312034000                 6.8
#
#      Divorces_per_1000
# 0                  0.3
# 1                  0.3
# 2                  0.3
# 3                  0.3
# 4                  0.3
# ..                 ...
# 140                2.8
# ...

# %%
years = US_divorce['Year']
marriages = US_divorce['Marriages_per_1000']
divorces = US_divorce['Divorces_per_1000']
US_divorce = plt.figure(figsize= (16,8))
US_divorce = plt.plot(years, marriages, label ='Marriages')
US_divorce = plt.plot(years, divorces, label = 'Divorces')
US_divorce = plt.title("marriages and divorces per capita in the U.S. (1867 to 2014)", fontsize=16)
US_divorce = plt.xlabel("Years", fontsize=16)
US_divorce = plt.legend(fontsize = 14)
US_divorce = plt.grid(True)
US_divorce

# %% [markdown]
# # Question 7

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('us-marriages-divorces-1867-2014.csv')

# %%
V = US_divorce.loc[US_divorce.Year.isin([1900,1950,2000]), ['Year', 'Marriages_per_1000', 'Divorces_per_1000']]
V
# Out:
#      Year  Marriages_per_1000  Divorces_per_1000
# 33   1900                 9.3                0.7
# 83   1950                11.0                2.5
# 133  2000                 8.2                3.3

# %%
years = V['Year']
marriages = V['Marriages_per_1000']
divorces = V['Divorces_per_1000']
V = plt.figure(figsize= (16,8))
V = plt.bar(years, marriages, label ='Marriages')
V = plt.bar(years, divorces, label = 'Divorces')
V = plt.title("Number of marriages and divorces per capita in the U.S. between 1990,1950 and 2000", fontsize=16)
V = plt.xlabel("Years", fontsize=14)
V = plt.legend(fontsize = 12, loc = "upper left")
V

# %% [markdown]
# # Question 8

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Actor_kill = pd.read_csv('actor_kill_counts.csv')
Actor_kill
# Out:
#                    Actor  Count
# 0  Arnold Schwarzenegger    369
# 1           Chow Yun-Fat    295
# 2         Clint Eastwood    207
# 3             Clive Owen    194
# 4         Dolph Lundgren    239
# 5                 Jet Li    201
# 6           Nicolas Cage    204
# 7     Sylvester Stallone    267
# 8    Tomisaburo Wakayama    226
# 9          Wesley Snipes    193

# %%
actor_name = Actor_kill['Actor']
kill_count = Actor_kill['Count']
Actor_kill = plt.figure(figsize= (13,6))
Actor_kill = plt.barh(actor_name, kill_count,label ='actor')
Actor_kill = plt.title("The deadliest actors in Hollywood", fontsize=18)
Actor_kill = plt.xlabel("kill count", fontsize=14)
Actor_kill = plt.legend(fontsize = 12, loc = "upper right")
Actor_kill

# %% [markdown]
# # Question 9

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("roman-emperor-reigns.csv")

# %%
data = data[data["Cause_of_Death"]=="Assassinated"]

# %%
patches, texts = plot.pie(data.Length_of_Reign)
plt.legend(data.Emperor)
plt.show()

# %% [markdown]
# # Question 10

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot

# %%
data = pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')
data
# Out:
#    Year  Revenue  Awards
# 0  2000    1.196     861
# 1  2001    1.176     830
# 2  2002    1.269     809
# 3  2003    1.240     867
# 4  2004    1.307     948
# 5  2005    1.435    1129
# 6  2006    1.601    1453
# 7  2007    1.654    1656
# 8  2008    1.803    1787
# 9  2009    1.734    1611

# %%
x = data.groupby('Year')
for name , group in x:
    plot.plot(group.Revenue, group.Awards, marker='o', linestyle='', markersize=12, label=name)  
plot.legend()
plot.xlabel("total revenue earned by arcades") 
plot.ylabel("Computer Science PhDs awarded")
plot.figure(figsize=(17,10))
